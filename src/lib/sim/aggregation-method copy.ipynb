# %% [markdown]
# $\hat{d}_{k}$ を以下の区間重要度推定問題の最適値とする。
# $$
#     \begin{align}
#         \begin{split}
#             \text{minimize} ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L}) \\
#             \text{subject to} ~~ & ~~ w_{ki}^{\rm L}\leq a_{kij}w_{kj}^{\rm U},\, a_{kij}w_{kj}^{\rm L}\leq w_{ki}^{\rm U},\, i<j,i,j\in N \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm U} + w_{ki}^{\rm L}\geq 1, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm L} + w_{ki}^{\rm U}\leq 1, i\in N, \\
#             ~~ & ~~ w_{ki}^{\rm U}\geq w_{ki}^{\rm L}\geq \epsilon, i\in N
#         \end{split}
#     \end{align}
# $$
#
# ### entani論文の統合手法
#
# Perfect incorporation apploach
# $$
#     \begin{align}
#         \begin{split}
#             \text{minimize} ~~ & ~~ \sum_{i\in N} (w_{i}^{\rm U} - w_{i}^{\rm L}) \\
#             \text{subject to} ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L}) \leq \hat{d_{k}} , k\in M \\
#             ~~ & ~~ w_{ki}^{\rm L}\leq a_{kij}w_{kj}^{R},\, a_{kij}w_{kj}^{\rm L}\leq w_{ki}^{\rm U},\, i<j, i,j\in N , k\in M\\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{R} + w_{ki}^{\rm L}\geq 1, i\in N, k\in M, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm L} + w_{ki}^{\rm U}\leq 1, i\in N, k\in M, \\
#             ~~ & ~~ \epsilon \leq w_{i}^{\rm L}\leq w_{ki}^{\rm L}\leq w_{ki}^{\rm U} \leq w_{i}^{\rm U}, k\in M, i\in N
#         \end{split}
#
#     \end{align}
# $$
#
# Common ground apploach
# $$
#     \begin{align}
#         \begin{split}
#             \text{maximize} ~~ & ~~ \sum_{i\in N} (w_{i}^{\rm U} - w_{i}^{\rm L}) \\
#             \text{subject to} ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L}) \leq \hat{d_{k}} , k\in M \\
#             ~~ & ~~ w_{ki}^{\rm L}\leq a_{kij}w_{kj}^{\rm U},\, a_{kij}w_{kj}^{\rm L}\leq w_{ki}^{\rm U},\, i<j, i,j\in N , k\in M\\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm U} + w_{ki}^{\rm L}\geq 1, i\in N, k\in M, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm L} + w_{ki}^{\rm U}\leq 1, i\in N, k\in M, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{j}^{\rm U} + w_{i}^{\rm L}\geq 1, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{j}^{\rm L} + w_{i}^{\rm U}\leq 1, i\in N, \\
#             ~~ & ~~ \epsilon \leq w_{ki}^{\rm L}\leq w_{i}^{\rm L}\leq w_{i}^{\rm U}\leq w_{ki}^{\rm U}, k\in M, i\in N
#         \end{split}
#     \end{align}
# $$
#
# Partial incorporation apploach
# $$
#     \begin{align}
#         \begin{split}
#             \text{minimize} ~~ & ~~ \sum_{i\in N} (w_{i}^{\rm U} - w_{i}^{\rm L}) \\
#             \text{subject to}  ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L}) \leq \hat{d_{k}} , k\in M \\
#             ~~ & ~~ w_{ki}^{\rm L}\leq a_{kij}w_{kj}^{\rm U},\, a_{kij}w_{kj}^{\rm L}\leq w_{ki}^{\rm U},\, i<j, i,j\in N , k\in M\\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm U} + w_{ki}^{\rm L}\geq 1, i\in N, k\in M, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm L} + w_{ki}^{\rm U}\leq 1, i\in N, k\in M, \\
#             ~~ & ~~ \sum_{i\in N} w_{ki} = 1, k\in M, \\
#             ~~ & ~~ \epsilon \leq w_{i}^{\rm L}\leq w_{ki}\leq w_{ki}^{\rm U}, \epsilon \leq w_{ki}^{\rm L}\leq w_{ki}\leq w_{i}^{\rm U}, k\in M, i\in N
#         \end{split}
#     \end{align}
# $$
#
#
# 以下の線形分数計画問題を考える。
# $$
#     \begin{align}
#         \begin{split}
#             \text{minimize} ~~ & ~~ \frac{\sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L})}{\sum_{i\in N} \frac{w_{ki}^{\rm U} + w_{ki}^{\rm L}}{2}} \\
#             \text{subject to} ~~ & ~~ w_{ki}^{\rm L}\leq a_{kij}w_{kj}^{\rm U},\, a_{kij}w_{kj}^{\rm L}\leq w_{ki}^{\rm U},\, i<j,i,j\in N \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm U} + w_{ki}^{\rm L}\geq 1, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm L} + w_{ki}^{\rm U}\leq 1, i\in N, \\
#             ~~ & ~~ w_{ki}^{\rm U}\geq w_{ki}^{\rm L}\geq \epsilon, i\in N
#         \end{split}
#     \end{align}
# $$
#
# ここで、
# $$
#     \begin{align}
#         \begin{split}
#             ~~ & ~~ \frac{1}{\sum_{i\in N} \frac{w_{ki}^{\rm L} + w_{ki}^{\rm U}}{2}} = p \\
#             \Leftrightarrow ~~ & ~~ \sum_{i\in Ñ} \frac{pw_{ki}^{\rm L}+pw_{ki}^{\rm U}}{2} = 1
#         \end{split}
#     \end{align}
# $$
#
# 以下のように $ŵ_{ki}^{\rm L}$、$ŵ_{ik}^{\rm U}$ を定義する
# $$
#     \begin{align}
#             ~~ & ~~ ŵ_{ki}^{\rm L} = pw_{ki}^{\rm L} \\
#             ~~ & ~~ ŵ_{ki}^{\rm U} = pw_{ki}^{\rm U}
#     \end{align}
# $$
#
# 問題(5)は問題(9)と等価である。
# $$
#     \begin{align}
#         \begin{split}
#             \text{minimize} ~~ & ~~ \sum_{i\in N} (ŵ_{ki}^{\rm U} - ŵ_{ki}^{\rm L}) \\
#             \text{subject to} ~~ & ~~ ŵ_{ki}^{\rm L}\leq a_{kij}ŵ_{kj}^{\rm U},\, a_{kij}ŵ_{kj}^{\rm L}\leq ŵ_{ki}^{\rm U},\, i<j,i,j\in N \\
#             ~~ & ~~ \sum_{j\in N\setminus i} ŵ_{kj}^{\rm U} + ŵ_{ki}^{\rm L}\geq p, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} ŵ_{kj}^{\rm L} + ŵ_{ki}^{\rm U}\leq p, i\in N, \\
#             ~~ & ~~ \sum_{i\in N} \frac{(ŵ_{ki}^{\rm U} + ŵ_{ki}^{\rm L})}{2} = 1 \\
#             ~~ & ~~ ŵ_{ki}^{\rm U}\geq ŵ_{ki}^{\rm L}\geq \epsilon, i\in N, \\
#             ~~ & ~~ p\geq \epsilon
#         \end{split}
#     \end{align}
# $$
#
# また、問題(9)と問題(10)は同値である。(証明による)
# $\hat{\delta}_{k}$ を以下の区間重要度推定問題(問題(10))の最適値とする。
#
# $$
#     \begin{align}
#         \begin{split}
#             \text{minimize} ~~ & ~~ \sum_{i\in N} w_{ki}^{\rm U} - w_{ki}^{\rm L} \\
#             \text{subject to} ~~ & ~~ w_{ki}^{\rm L}\leq a_{kij}w_{kj}^{\rm U},\, a_{kij}w_{kj}^{\rm L}\leq w_{ki}^{\rm U},\, i<j,i,j\in N \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm U} + w_{ki}^{\rm L}\geq 1, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm L} + w_{ki}^{\rm U}\leq 1, i\in N, \\
#             ~~ & ~~ \sum_{i\in N} \frac{w_{ki}^{\rm U} + w_{ki}^{\rm L}}{2} = 1 \\
#             ~~ & ~~ w_{ki}^{\rm U}\geq w_{ki}^{\rm L}\geq \epsilon, i\in N
#         \end{split}
#     \end{align}
# $$
#
# ### 中心総和1の統合手法
#
# Perfect incorporation apploach
# $$
#     \begin{align}
#         \begin{split}
#             \text{minimize} ~~ & ~~ \sum_{i\in N} (w_{i}^{\rm U} - w_{i}^{\rm L}) \\
#             \text{subject to} ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L}) \leq \hat{\delta}_{k} , k\in M \\
#             ~~ & ~~ w_{ki}^{\rm L}\leq a_{kij}w_{kj}^{R},\, a_{kij}w_{kj}^{\rm L}\leq w_{ki}^{\rm U},\, i<j, i,j\in N , k\in M\\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{R} + w_{ki}^{\rm L}\geq 1, i\in N, k\in M, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm L} + w_{ki}^{\rm U}\leq 1, i\in N, k\in M, \\
#             ~~ & ~~ \sum_{i\in N} \frac{w_{ki}^{\rm U} + w_{ki}^{\rm L}}{2} = 1, k\in M,  \\
#             ~~ & ~~ \sum_{i\in N} \frac{w_{i}^{\rm L} + w_{i}^{\rm U}}{2} = 1,  \\
#             ~~ & ~~ \epsilon \leq w_{i}^{\rm L}\leq w_{ki}^{\rm L}\leq w_{ki}^{\rm U} \leq w_{i}^{\rm U}, k\in M, i\in N
#         \end{split}
#
#     \end{align}
# $$
#
# Common ground apploach
# $$
#     \begin{align}
#         \begin{split}
#             \text{maximize} ~~ & ~~ \sum_{i\in N} (w_{i}^{\rm U} - w_{i}^{\rm L}) \\
#             \text{subject to} ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L}) \leq \hat{\delta}_{k} , k\in M \\
#             ~~ & ~~ w_{ki}^{\rm L}\leq a_{kij}w_{kj}^{\rm U},\, a_{kij}w_{kj}^{\rm L}\leq w_{ki}^{\rm U},\, i<j, i,j\in N , k\in M\\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm U} + w_{ki}^{\rm L}\geq 1, i\in N, k\in M, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm L} + w_{ki}^{\rm U}\leq 1, i\in N, k\in M, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{j}^{\rm U} + w_{i}^{\rm L}\geq 1, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{j}^{\rm L} + w_{i}^{\rm U}\leq 1, i\in N, \\
#             ~~ & ~~ \sum_{i\in N} \frac{w_{ki}^{\rm U} + w_{ki}^{\rm L}}{2} = 1, k\in M,  \\
#             ~~ & ~~ \sum_{i\in N} \frac{w_{i}^{\rm L} + w_{i}^{\rm U}}{2} = 1,  \\
#             ~~ & ~~ \epsilon \leq w_{ki}^{\rm L}\leq w_{i}^{\rm L}\leq w_{i}^{\rm U}\leq w_{ki}^{\rm U}, k\in M, i\in N
#         \end{split}
#     \end{align}
# $$
#
# Partial incorporation apploach
# $$
#     \begin{align}
#         \begin{split}
#             \text{minimize} ~~ & ~~ \sum_{i\in N} (w_{i}^{\rm U} - w_{i}^{\rm L}) \\
#             \text{subject to}  ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L}) \leq \hat{\delta}_{k} , k\in M \\
#             ~~ & ~~ w_{ki}^{\rm L}\leq a_{kij}w_{kj}^{\rm U},\, a_{kij}w_{kj}^{\rm L}\leq w_{ki}^{\rm U},\, i<j, i,j\in N , k\in M\\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm U} + w_{ki}^{\rm L}\geq 1, i\in N, k\in M, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm L} + w_{ki}^{\rm U}\leq 1, i\in N, k\in M, \\
#             ~~ & ~~ \sum_{i\in N} w_{ki} = 1, k\in M, \\
#             ~~ & ~~ \sum_{i\in N} \frac{w_{ki}^{\rm U} + w_{ki}^{\rm L}}{2} = 1, k\in M,  \\
#             ~~ & ~~ \sum_{i\in N} \frac{w_{i}^{\rm L} + w_{i}^{\rm U}}{2} = 1,  \\
#             ~~ & ~~ \epsilon \leq w_{i}^{\rm L}\leq w_{ki}\leq w_{ki}^{\rm U}, \epsilon \leq w_{ki}^{\rm L}\leq w_{ki}\leq w_{i}^{\rm U}, k\in M, i\in N
#         \end{split}
#     \end{align}
# $$
#
# ### 解の非唯一性を考慮した統合手法
#
# Perfect incorporation apploach(線形分数)
# $$
#     \begin{align}
#         \begin{split}
#             \text{minimize} ~~ & ~~ \frac{\sum_{i\in N} (w_{i}^{\rm U} - w_{i}^{\rm L})}{\sum_{i\in N} \frac {w_{i}^{\rm L} + w_{i}^{\rm U}}{2}} \\
#             \text{subject to} ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L}) \leq \sum_{i\in N} \frac{w_{ki}^{\rm U} + w_{ki}^{\rm L}}{2}\hat{\delta}_{k} , k\in M \\
#             ~~ & ~~ w_{ki}^{\rm L}\leq a_{kij}w_{kj}^{R},\, a_{kij}w_{kj}^{\rm L}\leq w_{ki}^{\rm U},\, i<j, i,j\in N , k\in M\\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{R} + w_{ki}^{\rm L}\geq 1, i\in N, k\in M, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm L} + w_{ki}^{\rm U}\leq 1, i\in N, k\in M, \\
#             ~~ & ~~ \epsilon \leq w_{i}^{\rm L}\leq w_{ki}^{\rm L}\leq w_{ki}^{\rm U} \leq w_{i}^{\rm U}, k\in M, i\in N
#         \end{split}
#     \end{align}
# $$
#
# ここで、
# $$
#     \begin{align}
#         \begin{split}
#             ~~ & ~~ \frac{1}{\sum_{i\in N} \frac{w_{i}^{\rm L} + w_{i}^{\rm U}}{2}} = t \\
#             \Leftrightarrow ~~ & ~~ \sum_{i\in Ñ} \frac{tw_{i}^{\rm L}+tw_{i}^{\rm U}}{2} = 1
#         \end{split}
#     \end{align}
# $$
#
# 以下のように $v_{i}^{\rm L}$、$v_{i}^{\rm U}$、$v_{ki}^{\rm L}$、$v_{ik}^{\rm U}$ を定義する
# $$
#     \begin{align}
#             ~~ & ~~ v_{i}^{\rm L} = tw_{i}^{\rm L} \\
#             ~~ & ~~ v_{i}^{\rm U} = tw_{i}^{\rm U} \\
#             ~~ & ~~ v_{ki}^{\rm L} = tw_{ki}^{\rm L} \\
#             ~~ & ~~ v_{ki}^{\rm U} = tw_{ki}^{\rm U}
#     \end{align}
# $$
#
# Perfect incorporation apploach
# $$
#     \begin{align}
#         \begin{split}
#             \text{minimize} ~~ & ~~ \sum_{i\in N} (v_{i}^{\rm U} - v_{i}^{\rm L}) \\
#             \text{subject to} ~~ & ~~ \sum_{i\in N} (v_{ki}^{\rm U} - v_{ki}^{\rm L})\leq \sum_{i\in N} \frac{v_{ki}^{\rm U} + v_{ki}^{\rm L}}{2}\hat{\delta}_{k} , k\in M \\
#             ~~ & ~~ v_{ki}^{\rm L}\leq a_{kij}v_{kj}^{\rm U},\, a_{kij}v_{kj}^{\rm L}\leq v_{ki}^{\rm U},\, i<j, i,j\in N , k\in M\\
#             ~~ & ~~ \sum_{j\in N\setminus i} v_{kj}^{\rm U} + v_{ki}^{\rm L}\geq t, i\in N, k\in M, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} v_{kj}^{\rm L} + v_{ki}^{\rm U}\leq t, i\in N, k\in M, \\
#             ~~ & ~~ \sum_{i\in N} \frac{v_{i}^{\rm U} + v_{i}^{\rm L}}{2} = 1, \\
#             ~~ & ~~ \epsilon \leq v_{i}^{\rm L}\leq v_{ki}^{\rm L}\leq v_{ki}^{\rm U} \leq v_{i}^{\rm U}, k\in M, i\in N, \\
#             ~~ & ~~ t\geq \epsilon
#         \end{split}
#     \end{align}
# $$
#
# Common ground apploach(線形分数)
# $$
#     \begin{align}
#         \begin{split}
#             \text{maximize} ~~ & ~~ \frac{\sum_{i\in N} (w_{i}^{\rm U} - w_{i}^{\rm L})}{\sum_{i\in N} \frac {w_{i}^{\rm L} + w_{i}^{\rm U}}{2}} \\
#             \text{subject to} ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L})\leq \sum_{i\in N} \frac{w_{ki}^{\rm U} + w_{ki}^{\rm L}}{2}\hat{\delta}_{k} , k\in M \\
#             ~~ & ~~ w_{ki}^{\rm L}\leq a_{kij}w_{kj}^{\rm U},\, a_{kij}w_{kj}^{\rm L}\leq w_{ki}^{\rm U},\, i<j, i,j\in N , k\in M\\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm U} + w_{ki}^{\rm L}\geq 1, i\in N, k\in M, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm L} + w_{ki}^{\rm U}\leq 1, i\in N, k\in M, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{j}^{\rm U} + w_{i}^{\rm L}\geq 1, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{j}^{\rm L} + w_{i}^{\rm U}\leq 1, i\in N, \\
#             ~~ & ~~ \epsilon \leq w_{ki}^{\rm L}\leq w_{i}^{\rm L}\leq w_{i}^{\rm U}\leq w_{ki}^{\rm U}, k\in M, i\in N
#         \end{split}
#     \end{align}
# $$
#
# Common ground apploach
# $$
#     \begin{align}
#         \begin{split}
#             \text{maximize} ~~ & ~~ \sum_{i\in N} (v_{i}^{\rm U} - v_{i}^{\rm L}) \\
#             \text{subject to} ~~ & ~~ \sum_{i\in N} (v_{ki}^{\rm U} - v_{ki}^{\rm L})\leq \sum_{i\in N} \frac{v_{ki}^{\rm U} + v_{ki}^{\rm L}}{2}\hat{\delta}_{k} , k\in M \\
#             ~~ & ~~ v_{ki}^{\rm L}\leq a_{kij}v_{kj}^{\rm U},\, a_{kij}v_{kj}^{\rm L}\leq v_{ki}^{\rm U},\, i<j, i,j\in N , k\in M\\
#             ~~ & ~~ \sum_{j\in N\setminus i} v_{kj}^{\rm U} + v_{ki}^{\rm L}\geq t, i\in N, k\in M, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} v_{kj}^{\rm L} + v_{ki}^{\rm U}\leq t, i\in N, k\in M, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} v_{j}^{\rm U} + v_{i}^{\rm L}\geq 1, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} v_{j}^{\rm L} + v_{i}^{\rm U}\leq 1, i\in N, \\
#             ~~ & ~~ \sum_{i\in N} \frac{v_{i}^{\rm U} + v_{i}^{\rm L}}{2} = 1,  \\
#             ~~ & ~~ \epsilon \leq v_{ki}^{\rm L}\leq v_{i}^{\rm L}\leq v_{i}^{\rm U}\leq v_{ki}^{\rm U}, i\in N, k\in M, \\
#             ~~ & ~~ t\geq \epsilon
#         \end{split}
#     \end{align}
# $$
#
# Partial incorporation apploach(線形分数)
# $$
#     \begin{align}
#         \begin{split}
#             \text{minimize} ~~ & ~~ \frac{\sum_{i\in N} (w_{i}^{\rm U} - w_{i}^{\rm L})}{\sum_{i\in N} \frac {w_{i}^{\rm L} + w_{i}^{\rm U}}{2}} \\
#             \text{subject to}  ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L})\leq \sum_{i\in N} \frac{w_{ki}^{\rm U} + w_{ki}^{\rm L}}{2}\hat{\delta}_{k} , k\in M \\
#             ~~ & ~~ w_{ki}^{\rm L}\leq a_{kij}w_{kj}^{\rm U},\, a_{kij}w_{kj}^{\rm L}\leq w_{ki}^{\rm U},\, i<j, i,j\in N , k\in M\\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm U} + w_{ki}^{\rm L}\geq 1, i\in N, k\in M, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm L} + w_{ki}^{\rm U}\leq 1, i\in N, k\in M, \\
#             ~~ & ~~ \sum_{i\in N} w_{ki} = 1, k\in M \\
#             ~~ & ~~ \epsilon \leq w_{i}^{\rm L}\leq w_{ki}\leq w_{ki}^{\rm U}, \epsilon \leq w_{ki}^{\rm L}\leq w_{ki}\leq w_{i}^{\rm U}, k\in M, i\in N
#         \end{split}
#     \end{align}
# $$
#
# Partial incorporation apploach
# $$
#     \begin{align}
#         \begin{split}
#             \text{minimize} ~~ & ~~ \sum_{i\in N} (v_{i}^{\rm U} - v_{i}^{\rm L}) \\
#             \text{subject to}  ~~ & ~~ \sum_{i\in N} (v_{ki}^{\rm U} - v_{ki}^{\rm L})\leq \sum_{i\in N} \frac{v_{ki}^{\rm U} + v_{ki}^{\rm L}}{2}\hat{\delta}_{k} , k\in M \\
#             ~~ & ~~ v_{ki}^{\rm L}\leq a_{kij}v_{kj}^{\rm U},\, a_{kij}v_{kj}^{\rm L}\leq v_{ki}^{\rm U},\, i<j, i,j\in N , k\in M\\
#             ~~ & ~~ \sum_{j\in N\setminus i} v_{kj}^{\rm U} + v_{ki}^{\rm L}\geq t, i\in N, k\in M, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} v_{kj}^{\rm L} + v_{ki}^{\rm U}\leq t, i\in N, k\in M, \\
#             ~~ & ~~ \sum_{i\in N} v_{ki} = t, k\in M \\
#             ~~ & ~~ \sum_{i\in N} \frac{v_{i}^{\rm U} + v_{i}^{\rm L}}{2} = 1,   \\
#             ~~ & ~~ \epsilon \leq v_{i}^{\rm L}\leq v_{ki}\leq v_{ki}^{\rm U}, \epsilon \leq v_{ki}^{\rm L}\leq v_{ki}\leq v_{i}^{\rm U}, i\in N, k\in M, \\
#             ~~ & ~~ t\geq \epsilon
#         \end{split}
#     \end{align}
# $$

# %% [markdown]
# ### クリスプPCの生成
#
# #### ステップ１
# 超平面上でのランダム点列の作り方によって総和１の重要度ベクトルを作る
# このとき、最大の要素と最小の要素の比は8.5〜9.5倍になるまで再生成を繰り返す
#
# #### ステップ2
# 重要度ベクトルからクリスプなPCMを作る
# このとき、saatyのスケールに基づいて数値を離散化する
#
# #### ステップ3
# ステップ2で作ったPCMをもとに、PCMの各要素の対数をとったものにに-aからaの一様分布から発生させた乱数を加える加える
# exp()でもとのスケールに戻す
# aは摂動の強度(今は0.65に設定)
#
# #### ステップ4
# ステップ3で生成したPCMをsaatyのスケールに離散化
#
# #### ステップ5
# C.I.のチェック
# 0.1以上ならステップ3に戻って再生成

# %% [markdown]
# ### 数値実験
#
# 基準数を4.5.6.7.8
# 人数は3人
#
# entani論文のPerfectIncorporation
# 中心総和1のPerfectIncorporation
# 解の非唯一性考慮のPerfectIncorporation
# entani論文のCommonGround
# 中心総和1のCommonGround
# 解の非唯一性考慮のCommonGround
# entani論文のPartialIncorporation
# 中心総和1のPartialIncorporation
# 解の非唯一性考慮のPartialIncorporation
#
# の9つで
# $$
#     \begin{equation}
#         (n-1) \sum_{i\in N} \log w_{i}^{\rm U} - \log w_{i}^{\rm L}
#     \end{equation}
# $$
# を計算する

# %% [markdown]
# ### モデルの改善案
#
# 再度、解の非唯一性について考えてみると
# 問題(1)の最適解は唯一でない場合があり、その解集合は問題(10) (中心総和を1とした問題)の最適解を標準解 $[w_{i}^{\rm L}, w_{i}^{\rm U}]$ としたとき
# $$
#     \begin{align}
#             ~~ & ~~ t^{\rm L} = \frac{1}{\min_{j} (\sum_{i≠j} w_{i}^{\rm L} + w_{j}^{\rm U})} \\
#             ~~ & ~~ t^{\rm U} = \frac{1}{\max_{j} (\sum_{i≠j} w_{i}^{\rm U} + w_{j}^{\rm L})}
#     \end{align}
# $$
#
# なる $t^{\rm L}$ と $t^{\rm U}$ を用いて $[tw_{i}^{\rm L}, tw_{i}^{\rm U}], i\in N, t^{\rm L}\leq t\leq t^{\rm U}$ と表せる。
#
# いま、問題(10)の最適値を $\hat{\delta}_{k}$ としているがこれは、元を辿れば問題(5)の最適値であり、(同じwを使っていて少しわかりづらいが...)
# $$
#     \begin{equation}
#         t_{k}^{\rm L}\hat{\delta}_{k}\leq \frac{\sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L})}{\sum_{i\in N} \frac{w_{ki}^{\rm U} + w_{ki}^{\rm L}}{2}}\leq t_{k}^{\rm U}\hat{\delta}_{k}
#     \end{equation}
# $$
#
# ここで式(6)を用いて書き直すと
# $$
#     \begin{equation}
#         t_{k}^{\rm L}\hat{\delta}_{k}\leq \sum_{i\in N} (pw_{ki}^{\rm U} - pw_{ki}^{\rm L})\leq t_{k}^{\rm U}\hat{\delta}_{k}
#     \end{equation}
# $$
#
# この範囲に入るような $[w_{ki}^{\rm L}, w_{ki}^{\rm U}]$ は全て、問題(10)の最適解である。
#
# とすると、、、
#
# 問題(2)、問題(3)、問題(4)の一つ目の最適性を保証する制約のところを変更するだけでいいのではないか？？
# $$
#     \begin{align}
#             ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L}) \leq \hat{d_{k}} , k\in M \\
#             \Rightarrow ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L}) \geq \sum_{i\in N} \frac{w_{ki}^{\rm U} + w_{ki}^{\rm L}}{2}t_{k}^{\rm L}\hat{\delta}_{k} , k\in M \\
#             ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L}) \leq \sum_{i\in N} \frac{w_{ki}^{\rm U} + w_{ki}^{\rm L}}{2}t_{k}^{\rm U}\hat{\delta}_{k} , k\in M
#     \end{align}
# $$
#
# これによって解の非唯一性を考慮して、
# それぞれのDMの区間を $p_{k} = \frac{1}{\sum_{i\in N} \frac{w_{ki}^{\rm L} + w_{ki}^{\rm U}}{2}}$ によって問題(10)の最適解である中で最も効果的に統合できるように選べるのではないか？
#
# この案に基づいてモデルを書き換える。
#
# 問題(10)の最適値を $\hat{\delta_{k}}$ 、最適解を $[w_{ki}^{\rm L}, w_{ki}^{\rm U}]$ として
# $$
#     \begin{align}
#             ~~ & ~~ t_{k}^{\rm L} = \frac{1}{\min_{j} (\sum_{i≠j} w_{ki}^{\rm L} + w_{kj}^{\rm U})} \\
#             ~~ & ~~ t_{k}^{\rm U} = \frac{1}{\max_{j} (\sum_{i≠j} w_{ki}^{\rm U} + w_{kxj}^{\rm L})}
#     \end{align}
# $$
#
# とすると、
#
# Perfect incorporation apploach
# $$
#     \begin{align}
#         \begin{split}
#             \text{minimize} ~~ & ~~ \sum_{i\in N} (w_{i}^{\rm U} - w_{i}^{\rm L}) \\
#             \text{subject to} ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L}) \geq \sum_{i\in N} \frac{w_{ki}^{\rm U} + w_{ki}^{\rm L}}{2}t_{k}^{\rm L}\hat{\delta}_{k} , k\in M \\
#             ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L}) \leq \sum_{i\in N} \frac{w_{ki}^{\rm U} + w_{ki}^{\rm L}}{2}t_{k}^{\rm U}\hat{\delta}_{k} , k\in M, \\
#             ~~ & ~~ w_{ki}^{\rm L}\leq a_{kij}w_{kj}^{R},\, a_{kij}w_{kj}^{\rm L}\leq w_{ki}^{\rm U},\, i<j, i,j\in N , k\in M\\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{R} + w_{ki}^{\rm L}\geq 1, i\in N, k\in M, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm L} + w_{ki}^{\rm U}\leq 1, i\in N, k\in M, \\
#             ~~ & ~~ \epsilon \leq w_{i}^{\rm L}\leq w_{ki}^{\rm L}\leq w_{ki}^{\rm U} \leq w_{i}^{\rm U}, k\in M, i\in N
#         \end{split}
#     \end{align}
# $$
#
# Common ground apploach
# $$
#     \begin{align}
#         \begin{split}
#             \text{maximize} ~~ & ~~ \sum_{i\in N} (w_{i}^{\rm U} - w_{i}^{\rm L}) \\
#             \text{subject to} ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L}) \geq \sum_{i\in N} \frac{w_{ki}^{\rm U} + w_{ki}^{\rm L}}{2}t_{k}^{\rm L}\hat{\delta}_{k} , k\in M \\
#             ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L}) \leq \sum_{i\in N} \frac{w_{ki}^{\rm U} + w_{ki}^{\rm L}}{2}t_{k}^{\rm U}\hat{\delta}_{k} , k\in M, \\
#             ~~ & ~~ w_{ki}^{\rm L}\leq a_{kij}w_{kj}^{\rm U},\, a_{kij}w_{kj}^{\rm L}\leq w_{ki}^{\rm U},\, i<j, i,j\in N , k\in M\\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm U} + w_{ki}^{\rm L}\geq 1, i\in N, k\in M, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm L} + w_{ki}^{\rm U}\leq 1, i\in N, k\in M, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{j}^{\rm U} + w_{i}^{\rm L}\geq 1, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{j}^{\rm L} + w_{i}^{\rm U}\leq 1, i\in N, \\
#             ~~ & ~~ \epsilon \leq w_{ki}^{\rm L}\leq w_{i}^{\rm L}\leq w_{i}^{\rm U}\leq w_{ki}^{\rm U}, k\in M, i\in N
#         \end{split}
#     \end{align}
# $$
#
# Partial incorporation apploach
# $$
#     \begin{align}
#         \begin{split}
#             \text{minimize} ~~ & ~~ \sum_{i\in N} (w_{i}^{\rm U} - w_{i}^{\rm L}) \\
#             \text{subject to} ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L}) \geq \sum_{i\in N} \frac{w_{ki}^{\rm U} + w_{ki}^{\rm L}}{2}t_{k}^{\rm L}\hat{\delta}_{k} , k\in M \\
#             ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L}) \leq \sum_{i\in N} \frac{w_{ki}^{\rm U} + w_{ki}^{\rm L}}{2}t_{k}^{\rm U}\hat{\delta}_{k} , k\in M, \\
#             ~~ & ~~ w_{ki}^{\rm L}\leq a_{kij}w_{kj}^{\rm U},\, a_{kij}w_{kj}^{\rm L}\leq w_{ki}^{\rm U},\, i<j, i,j\in N , k\in M\\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm U} + w_{ki}^{\rm L}\geq 1, i\in N, k\in M, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm L} + w_{ki}^{\rm U}\leq 1, i\in N, k\in M, \\
#             ~~ & ~~ \sum_{i\in N} w_{ki} = 1, k\in M \\
#             ~~ & ~~ \epsilon \leq w_{i}^{\rm L}\leq w_{ki}\leq w_{ki}^{\rm U}, \epsilon \leq w_{ki}^{\rm L}\leq w_{ki}\leq w_{i}^{\rm U}, k\in M, i\in N
#         \end{split}
#     \end{align}
# $$

# %% [markdown]
# 実際にこれで計算すると、
# 数値実験(pcmの生成法はこれまでと同様)
# DM数：3 、pcmのサイズ:5の場合に1000回
#
#
# ・PerfectIncorporation では995回が問題(2)より問題(34)の方が(25)式の値が小さくなった
#   (後の5回は問題(1)と問題(5)の解集合が異なり、問題(10)の $t^{\rm L}$ が問題(1)の会の中心の総和より小さくない時で
#     問題(2)の最適解は問題(35)で実行可能だった。)
#
# ・CommonGround では問題(3)と問題(36)のどちらの手法でも統合できたのが30回、問題(36)のみで統合できたのが950回
#
#
# ・PartialIncorporationでは全試行で問題(4)より問題(37)の方が(25)式の値が小さくなった

# %% [markdown]
# ### 問題(9)と問題(10)が同値であることの証明
#
# 問題(10)の最適解の一つを $w_{k}^{\ast} = [{w^{\ast}_{k}}^{\rm L}, {w^{\ast}_{k}}^{\rm U}]$ とする。
# $w_{k}^{\ast}$ は問題(10)の制約条件を満たすので以下を満たす。
# $$
#     \begin{align}
#         ~~ & ~~ {w^{\ast}_{ki}}^{\rm L}\leq a_{kij}{w^{\ast}_{kj}}^{\rm U} \\
#         ~~ & ~~ a_{kij}{w^{\ast}_{kj}}^{\rm L}\leq {w^{\ast}_{ki}}^{\rm U} \\
#         ~~ & ~~ \sum_{j\in N\setminus i} {w^{\ast}_{kj}}^{\rm U} + {w^{\ast}_{ki}}^{\rm L}\geq 1 \\
#         ~~ & ~~ \sum_{j\in N\setminus i} {w^{\ast}_{kj}}^{\rm L} + {w^{\ast}_{ki}}^{\rm U}\leq 1 \\
#         ~~ & ~~ \sum_{i\in N} \frac{{w^{\ast}_{ki}}^{\rm L} + {w^{\ast}_{ki}}^{\rm U}}{2} = 1 \\
#         ~~ & ~~ {w^{\ast}_{ki}}^{\rm U}\geq {w^{\ast}_{ki}}^{\rm L}\geq \epsilon, i\in N
#     \end{align}
# $$
#
# ここで
# $$
#     \begin{equation}
#         p = \frac{1}{\sum_{i\in N} \frac{{w^{\ast}_{ki}}^{\rm L} + {w^{\ast}_{ki}}^{\rm U}}{2}} = 1
#     \end{equation}
# $$
# として、新たに $v_{ki}^{\rm L} = p{w^{\ast}_{ki}}^{\rm L}, v_{ki}^{\rm U} = p{w^{\ast}_{ki}}^{\rm U}$ が問題(9)の最適解になるかどうかを考える。
#
# $p$ の定義より $p=1>0$ であるので(38)式、(39)式、(43)式の両辺を $p$ 倍することで
# $$
#     \begin{align}
#         ~~ & ~~ v_{ki}^{\rm L}\leq a_{kij}v_{kj}^{\rm U} \\
#         ~~ & ~~ a_{kij}v_{kj}^{\rm L}\leq v_{ki}^{\rm U} \\
#         ~~ & ~~ v_{ki}^{\rm U}\geq v_{ki}^{\rm L}\geq \epsilon
#     \end{align}
# $$
#
# また、
# $$
#     \begin{align}
#         ~~ & ~~ \sum_{j\in N\setminus i} v_{kj}^{\rm U} + v_{ki}v^{\rm L} = p(\sum_{j\in N\setminus i} {w^{\ast}_{kj}}^{\rm U} + {w^{\ast}_{ki}}^{\rm L})\geq p \\
#         ~~ & ~~ \sum_{j\in N\setminus i} v_{kj}^{\rm L} + v_{ki}v^{\rm U} = p(\sum_{j\in N\setminus i} {w^{\ast}_{kj}}^{\rm L} + {w^{\ast}_{ki}}^{\rm U})\leq p
#     \end{align}
# $$
#
# (44)式より
# $$
#     \begin{align}
#         ~~ & ~~ \sum_{i\in N} \frac{v_{ki}^{\rm L} + v_{ki}^{\rm U}}{2} = 1
#     \end{align}
# $$
#
# よって $v_{ki}^{\rm L}, v_{ki}^{\rm U}$ は問題(9)の全ての制約を満たす。
# ここで、この $v_{ki}^{\rm L}, v_{ki}^{\rm U}$ よりも問題(9)の目的関数値を小さくするような解 $v^{\ast}_{k} = [{v^{\ast}_{k}}^{\rm L}, {v^{\ast}_{k}}^{\rm U}]$ が存在することを仮定する。
# このとき、
# $$
#     \begin{align}
#         ~~ & ~~ \sum_{i\in N} (v_{ki}^{\rm L} - v_{ki}^{\rm U}) > \sum_{i\in N} ({v^{\ast}_{ki}}^{\rm L} - {v^{\ast}_{ki}}^{\rm U})
#     \end{align}
# $$
# を満たす。すなわち、問題(10)の最適解 $w_{k}^{\ast}$ が問題(9)の最適解にはならないことを仮定する。
# $v_{k}^{\ast}$ は問題(9)の制約条件を満たすので以下を満たす。
# $$
#     \begin{align}
#         ~~ & ~~ {v^{\ast}_{ki}}^{\rm L}\leq a_{kij}{v^{\ast}_{kj}}^{\rm U} \\
#         ~~ & ~~ a_{kij}{v^{\ast}_{kj}}^{\rm L}\leq {v^{\ast}_{ki}}^{\rm U} \\
#         ~~ & ~~ \sum_{j\in N\setminus i} {v^{\ast}_{kj}}^{\rm U} + {v^{\ast}_{ki}}^{\rm L}\geq p \\
#         ~~ & ~~ \sum_{j\in N\setminus i} {v^{\ast}_{kj}}^{\rm L} + {v^{\ast}_{ki}}^{\rm U}\leq p \\
#         ~~ & ~~ \sum_{i\in N} \frac{{v^{\ast}_{ki}}^{\rm L} + {v^{\ast}_{ki}}^{\rm U}}{2} = 1 \\
#         ~~ & ~~ {v^{\ast}_{ki}}^{\rm U}\geq {v^{\ast}_{ki}}^{\rm L}\geq \epsilon, i\in N
#     \end{align}
# $$
#
# このとき、 $w_{ki}^{\rm L} = \frac{{v^{\ast}_{ki}}^{\rm L}}{p}, w_{ki}^{\rm U} = \frac{{v^{\ast}_{ki}}^{\rm U}}{p}$ が問題(10)の最適解になるかどうかを考える。
#
# $p$ の定義より $p=1>0$ であるので(52)式、(53)式、(57)式の両辺を $\frac{1}{p}$ 倍することで
# $$
#     \begin{align}
#         ~~ & ~~ w_{ki}^{\rm L}\leq a_{kij}w_{kj}^{\rm U} \\
#         ~~ & ~~ a_{kij}w_{kj}^{\rm L}\leq w_{ki}^{\rm U} \\
#         ~~ & ~~ w_{ki}^{\rm U}\geq w_{ki}^{\rm L}\geq \epsilon
#     \end{align}
# $$
#
# また、
# $$
#     \begin{align}
#         ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm U} + w_{ki}v^{\rm L} = \frac{1}{p}(\sum_{j\in N\setminus i} {v^{\ast}_{kj}}^{\rm U} + {v^{\ast}_{ki}}^{\rm L})\geq 1 \\
#         ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm L} + w_{ki}v^{\rm U} = \frac{1}{p}(\sum_{j\in N\setminus i} {v^{\ast}_{kj}}^{\rm L} + {v^{\ast}_{ki}}^{\rm U})\leq 1
#     \end{align}
# $$
#
# (44)式より
# $$
#     \begin{align}
#         ~~ & ~~ \sum_{i\in N} \frac{w_{ki}^{\rm L} + w_{ki}^{\rm U}}{2} = \frac{1}{p}\sum_{i\in N} \frac{{v^{\ast}_{ki}}^{\rm L} + {v^{\ast}_{ki}}^{\rm U}}{2} = 1
#     \end{align}
# $$
#
# よって $w_{ki}^{\rm L}, w_{ki}^{\rm U}$ は問題(10)の全ての制約を満たす。
# ここで(51)式を両辺 $\frac{1}{p}$ 倍することで
# $$
#     \begin{align}
#         ~~ & ~~ \sum_{i\in N} ({w^{\ast}_{ki}}^{\rm L} - {w^{\ast}_{ki}}^{\rm U}) > \sum_{i\in N} (w_{ki}^{\rm L} - w_{ki}^{\rm U})
#     \end{align}
# $$
# 問題(10)において、$w_{k}$ の目的関数値が $w_{k}^{\ast}$ の目的関数値より小さくなるが、これは元々 $w_{k}^{\ast}$ が問題(10)の最適解であることに矛盾する。
# よって、問題(10)の最適解が問題(9)において最適ではないという仮定は矛盾しており、問題(10)の最適解は問題(9)においても最適解であるという結論が導かれる。
# また、問題(9)の最適解が問題(10)の最適解になることも同様にして導くことができる。
# 以上より、問題(9)と問題(10)は同値な問題である。
