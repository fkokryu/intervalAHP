# %% [markdown]
# $\hat{d}_{k}$ を以下の区間重要度推定問題の最適値とする。
# $$
#     \begin{align}
#         \begin{split}
#             \text{minimize} ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L}) \\
#             \text{subject to} ~~ & ~~ w_{ki}^{\rm L}\leq a_{kij}w_{kj}^{\rm U},\, a_{kij}w_{kj}^{\rm L}\leq w_{ki}^{\rm U},\, i,j,\in N(i<j) \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm U} + w_{ki}^{\rm L}\geq 1, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm L} + w_{ki}^{\rm U}\leq 1, i\in N, \\
#             ~~ & ~~ w_{ki}^{\rm U}\geq w_{ki}^{\rm L}\geq \epsilon, i\in N.
#         \end{split}
#     \end{align}
# $$
#
# ### entani論文の統合手法
#
# Perfect incorporation apploach
# $$
#     \begin{align}
#         \begin{split}
#             \text{minimize} ~~ & ~~ \sum_{i\in N} (w_{i}^{\rm U} - w_{i}^{\rm L}) \\
#             \text{subject to} ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L}) \leq \hat{d_{k}} , k\in M \\
#             ~~ & ~~ w_{ki}^{\rm L}\leq a_{kij}w_{kj}^{R},\, a_{kij}w_{kj}^{\rm L}\leq w_{ki}^{\rm U},\, i,j,\in N(i<j) , k\in M\\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{R} + w_{ki}^{\rm L}\geq 1, k\in M, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm L} + w_{ki}^{\rm U}\leq 1, k\in M, i\in N, \\
#             ~~ & ~~ \epsilon \leq w_{i}^{\rm L}\leq w_{ki}^{\rm L}\leq w_{ki}^{\rm U} \leq w_{i}^{\rm U}, k\in M, i\in N.
#         \end{split}
#
#     \end{align}
# $$
#
# Common ground apploach
# $$
#     \begin{align}
#         \begin{split}
#             \text{maximize} ~~ & ~~ \sum_{i\in N} (w_{i}^{\rm U} - w_{i}^{\rm L}) \\
#             \text{subject to} ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L}) \leq \hat{d_{k}} , k\in M \\
#             ~~ & ~~ w_{ki}^{\rm L}\leq a_{kij}w_{kj}^{\rm U},\, a_{kij}w_{kj}^{\rm L}\leq w_{ki}^{\rm U},\, i,j,\in N(i<j) , k\in M\\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm U} + w_{ki}^{\rm L}\geq 1, k\in M, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm L} + w_{ki}^{\rm U}\leq 1, k\in M, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{j}^{\rm U} + w_{i}^{\rm L}\geq 1, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{j}^{\rm L} + w_{i}^{\rm U}\leq 1, i\in N, \\
#             ~~ & ~~ \epsilon \leq w_{ki}^{\rm L}\leq w_{i}^{\rm L}\leq w_{i}^{\rm U}\leq w_{ki}^{\rm U}, k\in M, i\in N.
#         \end{split}
#     \end{align}
# $$
#
# Partial incorporation apploach
# $$
#     \begin{align}
#         \begin{split}
#             \text{minimize} ~~ & ~~ \sum_{i\in N} (w_{i}^{\rm U} - w_{i}^{\rm L}) \\
#             \text{subject to}  ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L}) \leq \hat{d_{k}} , k\in M \\
#             ~~ & ~~ w_{ki}^{\rm L}\leq a_{kij}w_{kj}^{\rm U},\, a_{kij}w_{kj}^{\rm L}\leq w_{ki}^{\rm U},\, i,j,\in N(i<j) , k\in M\\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm U} + w_{ki}^{\rm L}\geq 1, k\in M, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm L} + w_{ki}^{\rm U}\leq 1, k\in M, i\in N, \\
#             ~~ & ~~ \sum_{i\in N} w_{ki} = 1, k\in M, \\
#             ~~ & ~~ \epsilon \leq w_{i}^{\rm L}\leq w_{ki}\leq w_{ki}^{\rm U}, \epsilon \leq w_{ki}^{\rm L}\leq w_{ki}\leq w_{i}^{\rm U}, k\in M, i\in N.
#         \end{split}
#     \end{align}
# $$
#
#
# $\hat{\delta}_{k}$ を以下の区間重要度推定問題の最適値とする。
#
# $$
#     \begin{align}
#         \begin{split}
#             \text{minimize} ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L}) \\
#             \text{subject to} ~~ & ~~ w_{ki}^{\rm L}\leq a_{kij}w_{kj}^{\rm U},\, a_{kij}w_{kj}^{\rm L}\leq w_{ki}^{\rm U},\, i,j,\in N(i<j) \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm U} + w_{ki}^{\rm L}\geq 1, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm L} + w_{ki}^{\rm U}\leq 1, i\in N, \\
#             ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} + w_{ki}^{\rm L}) = 2 \\
#             ~~ & ~~ w_{ki}^{\rm U}\geq w_{ki}^{\rm L}\geq \epsilon, i\in N.
#         \end{split}
#     \end{align}
# $$
#
# ### 中心総和1の統合手法
#
# Perfect incorporation apploach
# $$
#     \begin{align}
#         \begin{split}
#             \text{minimize} ~~ & ~~ \sum_{i\in N} (w_{i}^{\rm U} - w_{i}^{\rm L}) \\
#             \text{subject to} ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L}) \leq \hat{\delta}_{k} , k\in M \\
#             ~~ & ~~ w_{ki}^{\rm L}\leq a_{kij}w_{kj}^{R},\, a_{kij}w_{kj}^{\rm L}\leq w_{ki}^{\rm U},\, i,j,\in N(i<j) , k\in M\\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{R} + w_{ki}^{\rm L}\geq 1, k\in M, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm L} + w_{ki}^{\rm U}\leq 1, k\in M, i\in N, \\
#             ~~ & ~~ \sum_{i\in N} \frac{w_{ki}^{\rm U} + w_{ki}^{\rm L}}{2} = 1, k\in M,  \\
#             ~~ & ~~ \sum_{i\in N} \frac{w_{i}^{\rm U} + w_{i}^{\rm L}}{2} = 1,  \\
#             ~~ & ~~ \epsilon \leq w_{i}^{\rm L}\leq w_{ki}^{\rm L}\leq w_{ki}^{\rm U} \leq w_{i}^{\rm U}, k\in M, i\in N.
#         \end{split}
#
#     \end{align}
# $$
#
# Common ground apploach
# $$
#     \begin{align}
#         \begin{split}
#             \text{maximize} ~~ & ~~ \sum_{i\in N} (w_{i}^{\rm U} - w_{i}^{\rm L}) \\
#             \text{subject to} ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L}) \leq \hat{\delta}_{k} , k\in M \\
#             ~~ & ~~ w_{ki}^{\rm L}\leq a_{kij}w_{kj}^{\rm U},\, a_{kij}w_{kj}^{\rm L}\leq w_{ki}^{\rm U},\, i,j,\in N(i<j) , k\in M\\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm U} + w_{ki}^{\rm L}\geq 1, k\in M, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm L} + w_{ki}^{\rm U}\leq 1, k\in M, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{j}^{\rm U} + w_{i}^{\rm L}\geq 1, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{j}^{\rm L} + w_{i}^{\rm U}\leq 1, i\in N, \\
#             ~~ & ~~ \sum_{i\in N} \frac{w_{ki}^{\rm U} + w_{ki}^{\rm L}}{2} = 1, k\in M,  \\
#             ~~ & ~~ \sum_{i\in N} \frac{w_{i}^{\rm U} + w_{i}^{\rm L}}{2} = 1,  \\
#             ~~ & ~~ \epsilon \leq w_{ki}^{\rm L}\leq w_{i}^{\rm L}\leq w_{i}^{\rm U}\leq w_{ki}^{\rm U}, k\in M, i\in N.
#         \end{split}
#     \end{align}
# $$
#
# Partial incorporation apploach
# $$
#     \begin{align}
#         \begin{split}
#             \text{minimize} ~~ & ~~ \sum_{i\in N} (w_{i}^{\rm U} - w_{i}^{\rm L}) \\
#             \text{subject to}  ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L}) \leq \hat{\delta}_{k} , k\in M \\
#             ~~ & ~~ w_{ki}^{\rm L}\leq a_{kij}w_{kj}^{\rm U},\, a_{kij}w_{kj}^{\rm L}\leq w_{ki}^{\rm U},\, i,j,\in N(i<j) , k\in M\\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm U} + w_{ki}^{\rm L}\geq 1, k\in M, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm L} + w_{ki}^{\rm U}\leq 1, k\in M, i\in N, \\
#             ~~ & ~~ \sum_{i\in N} w_{ki} = 1, k\in M, \\
#             ~~ & ~~ \sum_{i\in N} \frac{w_{ki}^{\rm U} + w_{ki}^{\rm L}}{2} = 1, k\in M,  \\
#             ~~ & ~~ \sum_{i\in N} \frac{w_{i}^{\rm U} + w_{i}^{\rm L}}{2} = 1,  \\
#             ~~ & ~~ \epsilon \leq w_{i}^{\rm L}\leq w_{ki}\leq w_{ki}^{\rm U}, \epsilon \leq w_{ki}^{\rm L}\leq w_{ki}\leq w_{i}^{\rm U}, k\in M, i\in N.
#         \end{split}
#     \end{align}
# $$
#
# ### 解の非唯一性を考慮した統合手法
#
# $$
#     \begin{align}
#         \begin{split}
#             ~~ & ~~ \frac{1}{\sum_{i\in N} \frac{w_{i}^{\rm L}+w_{i}^{\rm U}}{2}} = t \\
#             \Leftrightarrow ~~ & ~~ \sum_{i\in Ñ} \frac{tw_{i}^{\rm L}+tw_{i}^{\rm U}}{2} = 1
#         \end{split}
#     \end{align}
# $$
#
# 以下のように$v_{i}^{\rm L}$、$v_{i}^{\rm U}$、$v_{ki}^{\rm L}$、$v_{ik}^{\rm U}$定義
# $$
#     \begin{align}
#             ~~ & ~~ v_{i}^{\rm L} = tw_{i}^{\rm L} \\
#             ~~ & ~~ v_{i}^{\rm U} = tw_{i}^{\rm U} \\
#             ~~ & ~~ v_{ki}^{\rm L} = tw_{ki}^{\rm L} \\
#             ~~ & ~~ v_{ki}^{\rm U} = tw_{ki}^{\rm U}
#     \end{align}
# $$
#
# Perfect incorporation apploach
# $$
#     \begin{align}
#         \begin{split}
#             \text{minimize} ~~ & ~~ \sum_{i\in N} (v_{i}^{\rm U} - v_{i}^{\rm L}) \\
#             \text{subject to} ~~ & ~~ \sum_{i\in N} (v_{ki}^{\rm U} - v_{ki}^{\rm L}) = \sum_{i\in N} \frac{v_{ki}^{\rm U} + v_{ki}^{\rm L}}{2}\hat{\delta}_{k} , k\in M \\
#             ~~ & ~~ v_{ki}^{\rm L}\leq a_{kij}v_{kj}^{\rm U},\, a_{kij}v_{kj}^{\rm L}\leq v_{ki}^{\rm U},\, i,j,\in N(i<j) , k\in M\\
#             ~~ & ~~ \sum_{j\in N\setminus i} v_{kj}^{\rm U} + v_{ki}^{\rm L}\geq t, k\in M, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} v_{kj}^{\rm L} + v_{ki}^{\rm U}\leq t, k\in M, i\in N, \\
#             ~~ & ~~ \sum_{i\in N} \frac{v_{i}^{\rm U} + v_{i}^{\rm L}}{2} = 1, \\
#             ~~ & ~~ \epsilon \leq v_{i}^{\rm L}\leq v_{ki}^{\rm L}\leq v_{ki}^{\rm U} \leq v_{i}^{\rm U}, k\in M, i\in N.
#         \end{split}
#     \end{align}
# $$
#
# Common ground apploach(変更前)
# $$
#     \begin{align}
#         \begin{split}
#             \text{maximize} ~~ & ~~ \sum_{i\in N} (w_{i}^{\rm U} - w_{i}^{\rm L}) \\
#             \text{subject to} ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L}) = \sum_{i\in N} \frac{w_{ki}^{\rm U} + w_{ki}^{\rm L}}{2}\hat{\delta}_{k} , k\in M \\
#             ~~ & ~~ w_{ki}^{\rm L}\leq a_{kij}w_{kj}^{\rm U},\, a_{kij}w_{kj}^{\rm L}\leq w_{ki}^{\rm U},\, i,j,\in N(i<j) , k\in M\\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm U} + w_{ki}^{\rm L}\geq 1, k\in M, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm L} + w_{ki}^{\rm U}\leq 1, k\in M, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{j}^{\rm U} + w_{i}^{\rm L}\geq 1, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{j}^{\rm L} + w_{i}^{\rm U}\leq 1, i\in N, \\
#             ~~ & ~~ \sum_{i\in N} \frac{w_{i}^{\rm U} + w_{i}^{\rm L}}{2} = 1,  \\
#             ~~ & ~~ \epsilon \leq w_{ki}^{\rm L}\leq w_{i}^{\rm L}\leq w_{i}^{\rm U}\leq w_{ki}^{\rm U}, k\in M, i\in N.
#         \end{split}
#     \end{align}
# $$
#
# Common ground apploach(変更後?)
# $$
#     \begin{align}
#         \begin{split}
#             \text{maximize} ~~ & ~~ \sum_{i\in N} (v_{i}^{\rm U} - v_{i}^{\rm L}) \\
#             \text{subject to} ~~ & ~~ \sum_{i\in N} (v_{ki}^{\rm U} - v_{ki}^{\rm L}) = \sum_{i\in N} \frac{v_{ki}^{\rm U} + v_{ki}^{\rm L}}{2}\hat{\delta}_{k} , k\in M \\
#             ~~ & ~~ v_{ki}^{\rm L}\leq a_{kij}v_{kj}^{\rm U},\, a_{kij}v_{kj}^{\rm L}\leq v_{ki}^{\rm U},\, i,j,\in N(i<j) , k\in M\\
#             ~~ & ~~ \sum_{j\in N\setminus i} v_{kj}^{\rm U} + v_{ki}^{\rm L}\geq t, k\in M, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} v_{kj}^{\rm L} + v_{ki}^{\rm U}\leq t, k\in M, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} v_{j}^{\rm U} + v_{i}^{\rm L}\geq 1, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} v_{j}^{\rm L} + v_{i}^{\rm U}\leq 1, i\in N, \\
#             ~~ & ~~ \sum_{i\in N} \frac{v_{i}^{\rm U} + v_{i}^{\rm L}}{2} = 1,  \\
#             ~~ & ~~ \epsilon \leq v_{ki}^{\rm L}\leq v_{i}^{\rm L}\leq v_{i}^{\rm U}\leq v_{ki}^{\rm U}, k\in M, i\in N.
#         \end{split}
#     \end{align}
# $$
#
# Partial incorporation apploach(変更前)
# $$
#     \begin{align}
#         \begin{split}
#             \text{minimize} ~~ & ~~ \sum_{i\in N} (w_{i}^{\rm U} - w_{i}^{\rm L}) \\
#             \text{subject to}  ~~ & ~~ \sum_{i\in N} (w_{ki}^{\rm U} - w_{ki}^{\rm L}) = \sum_{i\in N} \frac{w_{ki}^{\rm U} + w_{ki}^{\rm L}}{2}\hat{\delta}_{k} , k\in M \\
#             ~~ & ~~ w_{ki}^{\rm L}\leq a_{kij}w_{kj}^{\rm U},\, a_{kij}w_{kj}^{\rm L}\leq w_{ki}^{\rm U},\, i,j,\in N(i<j) , k\in M\\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm U} + w_{ki}^{\rm L}\geq 1, k\in M, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} w_{kj}^{\rm L} + w_{ki}^{\rm U}\leq 1, k\in M, i\in N, \\
#             ~~ & ~~ \sum_{i\in N} w_{ki} = 1, k\in M \\
#             ~~ & ~~ \sum_{i\in N} \frac{w_{i}^{\rm U} + w_{i}^{\rm L}}{2} = 1,   \\
#             ~~ & ~~ \epsilon \leq w_{i}^{\rm L}\leq w_{ki}\leq w_{ki}^{\rm U}, \epsilon \leq w_{ki}^{\rm L}\leq w_{ki}\leq w_{i}^{\rm U}, k\in M, i\in N.
#         \end{split}
#     \end{align}
# $$
#
# Partial incorporation apploach(変更後?)
# $$
#     \begin{align}
#         \begin{split}
#             \text{minimize} ~~ & ~~ \sum_{i\in N} (v_{i}^{\rm U} - v_{i}^{\rm L}) \\
#             \text{subject to}  ~~ & ~~ \sum_{i\in N} (v_{ki}^{\rm U} - v_{ki}^{\rm L}) = \sum_{i\in N} \frac{v_{ki}^{\rm U} + v_{ki}^{\rm L}}{2}\hat{\delta}_{k} , k\in M \\
#             ~~ & ~~ v_{ki}^{\rm L}\leq a_{kij}v_{kj}^{\rm U},\, a_{kij}v_{kj}^{\rm L}\leq v_{ki}^{\rm U},\, i,j,\in N(i<j) , k\in M\\
#             ~~ & ~~ \sum_{j\in N\setminus i} v_{kj}^{\rm U} + v_{ki}^{\rm L}\geq t, k\in M, i\in N, \\
#             ~~ & ~~ \sum_{j\in N\setminus i} v_{kj}^{\rm L} + v_{ki}^{\rm U}\leq t, k\in M, i\in N, \\
#             ~~ & ~~ \sum_{i\in N} v_{ki} = 1, k\in M \\
#             ~~ & ~~ \sum_{i\in N} \frac{v_{i}^{\rm U} + v_{i}^{\rm L}}{2} = 1,   \\
#             ~~ & ~~ \epsilon \leq v_{i}^{\rm L}\leq v_{ki}\leq v_{ki}^{\rm U}, \epsilon \leq v_{ki}^{\rm L}\leq v_{ki}\leq v_{i}^{\rm U}, k\in M, i\in N.
#         \end{split}
#     \end{align}
# $$

# %% [markdown]
# ### クリスプPCの生成
#
# #### ステップ１
# 超平面上でのランダム点列の作り方によって総和１の重要度ベクトルを作る
# このとき、最大の要素と最小の要素の比は8.5〜9.5倍になるまで再生成を繰り返す
#
# #### ステップ2
# 重要度ベクトルからクリスプなPCMを作る
# このとき、saatyのスケールに基づいて数値を離散化する
#
# #### ステップ3
# ステップ2で作ったPCMをもとに、PCMの各要素の対数をとったものにに-aからaの一様分布から発生させた乱数を加える加える
# exp()でもとのスケールに戻す
# aは摂動の強度(今は0.65に設定)
#
# #### ステップ4
# ステップ3で生成したPCMをsaatyのスケールに離散化
#
# #### ステップ5
# C.I.のチェック
# 0.1以上ならステップ3に戻って再生成

# %% [markdown]
# ### 数値実験
#
# 基準数を4.5.6.7.8
# 人数は3人
#
# entani論文のPerfectIncorporation
# 中心総和1のPerfectIncorporation
# 解の非唯一性考慮のPerfectIncorporation
# entani論文のCommonGround
# 中心総和1のCommonGround
# 解の非唯一性考慮のCommonGround
# entani論文のPartialIncorporation
# 中心総和1のPartialIncorporation
# 解の非唯一性考慮のPartialIncorporation
#
# の9つで
# $$
# (n-1) \sum_{i\in N} \log w^{\rm U} - \log w^{\rm L}
# $$
# を計算する
